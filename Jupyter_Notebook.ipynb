# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Haochen Miao**
#
# Data Scientist

# %% [markdown]
# *The reason why I want to be a data scientist is because I love to make complicated data simple!*

# %% [markdown]
# ### this code finds the sum of three numbers

# %%
x = 1
y = 2
z = 3
sum = x + y + z
print(f'the sum of three numbers is: {sum}')
# Out:
# the sum of three numbers is: 6

# %% [markdown]
# [Link](https://www.wikipedia.org/)
#
# ![Dog.jpg](attachment:41def49e-5819-46b1-8a29-98e1f57ceefc.jpg)
#
# - Key features
#  - dog is black
#  - dog has a hat
#  - it is taken in July
